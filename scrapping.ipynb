# %%
import requests   # library to download files from internet

# the pdf link
url = "https://cgwb.gov.in/sites/default/files/inline-files/final_nhs-wq_pre_2023_compressed.pdf"

# the filename
filename ="ground_water_report2023.pdf"

# getting the file from the link
response = requests.get(url)

# checking if download was successful
if response.status_code == 200:
    # opening file in write-binary mode and saving
    with open(filename, "wb") as f:
        f.write(response.content)
    print("PDF downloaded and saved successfully!")
else:
    print("Failed to download. Error code:", response.status_code)
# Out:
# PDF downloaded and saved successfully!

# %%
import pdfplumber
import camelot
import pandas as pd

pdf_path = "ground_water_report2023.pdf"
output_csv = "groundwaterreport.csv"

tables_collected = []
header = None  # to store the first header row

with pdfplumber.open(pdf_path) as pdf:
    num_pages = len(pdf.pages)
    print(f"Total pages: {num_pages}")

    for page_num in range(1, num_pages+1):
        print(f"Processing page {page_num}/{num_pages}…", end="")

        try:
            # Try Camelot extraction
            cam = camelot.read_pdf(pdf_path, pages=str(page_num), flavor="lattice")
            if cam.n == 0:
                cam = camelot.read_pdf(pdf_path, pages=str(page_num), flavor="stream")

            if cam.n == 0:
                print(" – no tables.")
                continue

            for idx, tbl in enumerate(cam):
                df = tbl.df.dropna(how="all", axis=0).dropna(how="all", axis=1)

                # Capture header only from the very first table
                if header is None:
                    header = df.iloc[0].tolist()
                    df = df[1:]
                else:
                    # Drop header rows that repeat
                    if df.iloc[0].tolist() == header:
                        df = df[1:]

                df.columns = header
                df["source_page"] = page_num
                tables_collected.append(df)

            print(f" – extracted {cam.n} tables.")

        except Exception as e:
            print(" – error:", e)

# Combine all tables
if tables_collected:
    final_df = pd.concat(tables_collected, ignore_index=True)
    final_df.to_csv("groundwaterreport.csv", index=False)
    print(f"\n✅ Clean extraction complete! Saved to {output_csv}")
    print("Rows:", df.shape[0], " | Columns:", df.shape[1])
else:

    print("\n⚠️ No tables extracted.")
# Out:
# Total pages: 200
# Processing page 1/200… – extracted 1 tables.
# Processing page 2/200… – extracted 1 tables.
# Processing page 3/200… – extracted 1 tables.
# Processing page 4/200… – extracted 1 tables.
# Processing page 5/200… – extracted 1 tables.
# Processing page 6/200… – extracted 1 tables.
# Processing page 7/200… – extracted 1 tables.
# Processing page 8/200… – extracted 1 tables.
# Processing page 9/200… – extracted 1 tables.
# Processing page 10/200… – extracted 1 tables.
# Processing page 11/200… – extracted 1 tables.
# Processing page 12/200… – extracted 1 tables.
# Processing page 13/200… – extracted 1 tables.
# Processing page 14/200… – extracted 1 tables.
# Processing page 15/200… – extracted 1 tables.
# Processing page 16/200… – extracted 1 tables.
# Processing page 17/200… – extracted 1 tables.
# Processing page 18/200… – extracted 1 tables.
# Processing page 19/200… – extracted 1 tables.
# Processing page 20/200… – extracted 1 tables.
# Processing page 21/200… – extracted 1 tables.
# Processing page 22/200… – extracted 1 tables.
# Processing page 23/200… – extracted 1 tables.
# Processing page 24/200… – extracted 1 tables.
# Processing page 25/200… – extracted 1 tables.
# Processing page 26/200… – extracted 1 tables.
# Processing page 27/200… – extracted 1 tables.
# Processing page 28/200… – extracted 1 tables.
# Processing page 29/200… – extracted 1 tables.
# Processing page 30/200… – extracted 1 tables.
# Processing page 31/200… – extracted 1 tables.
# Processing page 32/200… – extracted 1 tables.
# Processing page 33/200… – extracted 1 tables.
# Processing page 34/200… – extracted 1 tables.
# Processing page 35/200… – extracted 1 tables.
# Processing page 36/200… – extracted 1 tables.
# Processing page 37/200… – extracted 1 tables.
# Processing page 38/200… – extracted 1 tables.
# Processing page 39/200… – extracted 1 tables.
# Processing page 40/200… – extracted 1 tables.
# Processing page 41/200… – extracted 1 tables.
# Processing page 42/200… – extracted 1 tables.
# Processing page 43/200… – extracted 1 tables.
# Processing page 44/200… – extracted 1 tables.
# Processing page 45/200… – extracted 1 tables.
# Processing page 46/200… – extracted 1 tables.
# Processing page 47/200… – extracted 1 tables.
# Processing page 48/200… – extracted 1 tables.
# Processing page 49/200… – extracted 1 tables.
# Processing page 50/200… – extracted 1 tables.
# Processing page 51/200… – extracted 1 tables.
# Processing page 52/200… – extracted 1 tables.
# Processing page 53/200… – extracted 1 tables.
# Processing page 54/200… – extracted 1 tables.
# Processing page 55/200… – extracted 1 tables.
# Processing page 56/200… – extracted 1 tables.
# Processing page 57/200… – extracted 1 tables.
# Processing page 58/200… – extracted 1 tables.
# Processing page 59/200… – extracted 1 tables.
# Processing page 60/200… – extracted 1 tables.
# Processing page 61/200… – extracted 1 tables.
# Processing page 62/200… – extracted 1 tables.
# Processing page 63/200… – extracted 1 tables.
# Processing page 64/200… – extracted 1 tables.
# Processing page 65/200… – extracted 1 tables.
# Processing page 66/200… – extracted 1 tables.
# Processing page 67/200… – extracted 1 tables.
# Processing page 68/200… – extracted 1 tables.
# Processing page 69/200… – extracted 1 tables.
# Processing page 70/200… – extracted 1 tables.
# Processing page 71/200… – extracted 1 tables.
# Processing page 72/200… – extracted 1 tables.
# Processing page 73/200… – extracted 1 tables.
# Processing page 74/200… – extracted 1 tables.
# Processing page 75/200… – extracted 1 tables.
# Processing page 76/200… – extracted 1 tables.
# Processing page 77/200… – extracted 1 tables.
# Processing page 78/200… – extracted 1 tables.
# Processing page 79/200… – extracted 1 tables.
# Processing page 80/200… – extracted 1 tables.
# Processing page 81/200… – extracted 1 tables.
# Processing page 82/200… – extracted 1 tables.
# Processing page 83/200… – extracted 1 tables.
# Processing page 84/200… – extracted 1 tables.
# Processing page 85/200… – extracted 1 tables.
# Processing page 86/200… – extracted 1 tables.
# Processing page 87/200… – extracted 1 tables.
# Processing page 88/200… – extracted 1 tables.
# Processing page 89/200… – extracted 1 tables.
# Processing page 90/200… – extracted 1 tables.
# Processing page 91/200… – extracted 1 tables.
# Processing page 92/200… – extracted 1 tables.
# Processing page 93/200… – extracted 1 tables.
# Processing page 94/200… – extracted 1 tables.
# Processing page 95/200… – extracted 1 tables.
# Processing page 96/200… – extracted 1 tables.
# Processing page 97/200… – extracted 1 tables.
# Processing page 98/200… – extracted 1 tables.
# Processing page 99/200… – extracted 1 tables.
# Processing page 100/200… – extracted 1 tables.
# Processing page 101/200… – extracted 1 tables.
# Processing page 102/200… – extracted 1 tables.
# Processing page 103/200… – extracted 1 tables.
# Processing page 104/200… – extracted 1 tables.
# Processing page 105/200… – extracted 1 tables.
# Processing page 106/200… – extracted 1 tables.
# Processing page 107/200… – extracted 1 tables.
# Processing page 108/200… – extracted 1 tables.
# Processing page 109/200… – extracted 1 tables.
# Processing page 110/200… – extracted 1 tables.
# Processing page 111/200… – extracted 1 tables.
# Processing page 112/200… – extracted 1 tables.
# Processing page 113/200… – extracted 1 tables.
# Processing page 114/200… – extracted 1 tables.
# Processing page 115/200… – extracted 1 tables.
# Processing page 116/200… – extracted 1 tables.
# Processing page 117/200… – extracted 1 tables.
# Processing page 118/200… – extracted 1 tables.
# Processing page 119/200… – extracted 1 tables.
# Processing page 120/200… – extracted 1 tables.
# Processing page 121/200… – extracted 1 tables.
# Processing page 122/200… – extracted 1 tables.
# Processing page 123/200… – extracted 1 tables.
# Processing page 124/200… – extracted 1 tables.
# Processing page 125/200… – extracted 1 tables.
# Processing page 126/200… – extracted 1 tables.
# Processing page 127/200… – extracted 1 tables.
# Processing page 128/200… – extracted 1 tables.
# Processing page 129/200… – extracted 1 tables.
# Processing page 130/200… – extracted 1 tables.
# Processing page 131/200… – extracted 1 tables.
# Processing page 132/200… – extracted 1 tables.
# Processing page 133/200… – extracted 1 tables.
# Processing page 134/200… – extracted 1 tables.
# Processing page 135/200… – extracted 1 tables.
# Processing page 136/200… – extracted 1 tables.
# Processing page 137/200… – extracted 1 tables.
# Processing page 138/200… – extracted 1 tables.
# Processing page 139/200… – extracted 1 tables.
# Processing page 140/200… – extracted 1 tables.
# Processing page 141/200… – extracted 1 tables.
# Processing page 142/200… – extracted 1 tables.
# Processing page 143/200… – extracted 1 tables.
# Processing page 144/200… – extracted 1 tables.
# Processing page 145/200… – extracted 1 tables.
# Processing page 146/200… – extracted 1 tables.
# Processing page 147/200… – extracted 1 tables.
# Processing page 148/200… – extracted 1 tables.
# Processing page 149/200… – extracted 1 tables.
# Processing page 150/200… – extracted 1 tables.
# Processing page 151/200… – extracted 1 tables.
# Processing page 152/200… – extracted 1 tables.
# Processing page 153/200… – extracted 1 tables.
# Processing page 154/200… – extracted 1 tables.
# Processing page 155/200… – extracted 1 tables.
# Processing page 156/200… – extracted 1 tables.
# Processing page 157/200… – extracted 1 tables.
# Processing page 158/200… – extracted 1 tables.
# Processing page 159/200… – extracted 1 tables.
# Processing page 160/200… – extracted 1 tables.
# Processing page 161/200… – extracted 1 tables.
# Processing page 162/200… – extracted 1 tables.
# Processing page 163/200… – extracted 1 tables.
# Processing page 164/200… – extracted 1 tables.
# Processing page 165/200… – extracted 1 tables.
# Processing page 166/200… – extracted 1 tables.
# Processing page 167/200… – extracted 1 tables.
# Processing page 168/200… – extracted 1 tables.
# Processing page 169/200… – extracted 1 tables.
# Processing page 170/200… – extracted 1 tables.
# Processing page 171/200… – extracted 1 tables.
# Processing page 172/200… – extracted 1 tables.
# Processing page 173/200… – extracted 1 tables.
# Processing page 174/200… – extracted 1 tables.
# Processing page 175/200… – extracted 1 tables.
# Processing page 176/200… – extracted 1 tables.
# Processing page 177/200… – extracted 1 tables.
# Processing page 178/200… – extracted 1 tables.
# Processing page 179/200… – extracted 1 tables.
# Processing page 180/200… – extracted 1 tables.
# Processing page 181/200… – extracted 1 tables.
# Processing page 182/200… – extracted 1 tables.
# Processing page 183/200… – extracted 1 tables.
# Processing page 184/200… – extracted 1 tables.
# Processing page 185/200… – extracted 1 tables.
# Processing page 186/200… – extracted 1 tables.
# Processing page 187/200… – extracted 1 tables.
# Processing page 188/200… – extracted 1 tables.
# Processing page 189/200… – extracted 1 tables.
# Processing page 190/200… – extracted 1 tables.
# Processing page 191/200… – extracted 1 tables.
# Processing page 192/200… – extracted 1 tables.
# Processing page 193/200… – extracted 1 tables.
# Processing page 194/200… – extracted 1 tables.
# Processing page 195/200… – extracted 1 tables.
# Processing page 196/200… – extracted 1 tables.
# Processing page 197/200… – extracted 1 tables.
# Processing page 198/200… – extracted 1 tables.
# Processing page 199/200… – extracted 1 tables.
# Processing page 200/200… – extracted 1 tables.
#
# ✅ Clean extraction complete! Saved to groundwaterreport.csv
# Rows: 16776  | Columns: 25
